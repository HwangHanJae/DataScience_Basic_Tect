# %% [markdown]
# ###set_matplotlib_formats의 어떤 옵션이 가장 폰트가 선명할까?

# %% [markdown]
# ###라이브러리 가져오기

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm 
import matplotlib as mpl

# %% [markdown]
# ###그래프 및 한글 폰트 기본설정

# %%
#그래프에서 격자로 숫자 범위가 눈에 잘 띄도록 ggplot 스타일 사용
plt.style.use('ggplot')
#그래프에서 마이너스 폰트 깨지는 문제 대한 대처
mpl.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ####시스템에 설치된 폰트 확인

# %%
print("fm.findSystemFonts() : ", len(fm.findSystemFonts()))
nanum_font = [f for f in fm.findSystemFonts() if "Nanum" in f]
print("nanum_font : ", len(nanum_font))
# Out:
# fm.findSystemFonts() :  48
# nanum_font :  31

# %% [markdown]
# ####한글 폰트 인스톨

# %%
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq
fm._rebuild()
nanum_font = [f for f in fm.findSystemFonts() if "Nanum" in f]
print("nanum_font : ", len(nanum_font))
# Out:
# nanum_font :  31

# %% [markdown]
# ####폰트 지정 및 확인

# %%
print("현재 설정 폰트 : ", plt.rcParams['font.family'])

#한글 폰트 경로(나눔바른고딕)
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font_name = fm.FontProperties(fname=fontpath).get_name()
#맷플롯립 라이브리에 폰트 설정
plt.rc('font',family=font_name)
print("현재 설정 폰트 : ", plt.rcParams['font.family'])
# Out:
# 현재 설정 폰트 :  ['sans-serif']
# 현재 설정 폰트 :  ['NanumBarunGothic']

# %% [markdown]
# ###데이터 로드하기
# - 사용한 데이터는 [소상공인시장진흥공단_상가업소정보_의료기관_201909.csv](https://www.data.go.kr/data/15069540/fileData.do)

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/DataScience/Data/소상공인시장진흥공단_상가업소정보_의료기관_201909.csv',low_memory=False)

# %% [markdown]
# ###set_matplotlib_formats()사용하여 각 옵션 비교해보기

# %%
from IPython.display import set_matplotlib_formats

# %%
set_matplotlib_formats?

# %%
#1.png 옵션
set_matplotlib_formats('png')
df['시도명'].value_counts().plot.barh(figsize=(10,10))

# %%
#2.retina 옵션
set_matplotlib_formats('retina')
df['시도명'].value_counts().plot.barh(figsize=(10,10))

# %%
#3.jpeg 옵션
set_matplotlib_formats('jpeg')
df['시도명'].value_counts().plot.barh(figsize=(10,10))

# %%
#4.svg 옵션
set_matplotlib_formats('svg')
df['시도명'].value_counts().plot.barh(figsize=(10,10))

# %%
#4.pdf 옵션
set_matplotlib_formats('pdf')
df['시도명'].value_counts().plot.barh(figsize=(10,10))
